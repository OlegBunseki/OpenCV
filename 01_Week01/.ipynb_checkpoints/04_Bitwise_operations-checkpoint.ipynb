# %% [markdown]
# # <font style="color:rgb(50,120,229)">Bitwise Operations </font>
#
# So far we have had a look at some basic arithmetic operations. Now it's time to study the last set of operations in this module - bitwise operations. We will focus on the following bitwise operations.
#
# **AND operation**: [**`cv2.bitwise_and`**](https://docs.opencv.org/4.1.0/d2/de8/group__core__array.html#ga60b4d04b251ba5eb1392c34425497e14)
#
# **OR operation**: [**`cv2.bitwise_or`**](https://docs.opencv.org/4.1.0/d2/de8/group__core__array.html#gab85523db362a4e26ff0c703793a719b4)
#
# **NOT operation**: [**`cv2.bitwise_not`**](https://docs.opencv.org/4.1.0/d2/de8/group__core__array.html#ga0002cf8b418479f4cb49a75442baee2f)
#
# **XOR operation**: [**`cv2.bitwise_xor`**](https://docs.opencv.org/4.1.0/d2/de8/group__core__array.html#ga84b2d8188ce506593dcc3f8cd00e8e2c)
#
#
# Among all the bitwise operations, the AND operation is the most used.

# %% [markdown]
# ### <font style = "color:rgb(8,133,37)">Function Syntax</font>
# ```python
# dst	=	cv2.bitwise_XXX(	src1, src2[, dst[, mask]]	)
# ```
#
# XXX stands for the operation
#
# **Parameters**
#
# - **`src1`**	- first input.
# - **`src2`**	- second input.
# - **`dst`**	- output array that has the same size and type as the input array.
# - **`mask`** - optional operation mask, 8-bit single channel array, that specifies elements of the output array to be changed. The operation is applied only on those pixels of the input images where the mask is non-zero.
#
# **The operation is applied elementwise between two matrices. The two inputs should be of the same size for this operation.**

# %% [markdown]
# Here's a cheat sheet on the input and output table for these bitwise operations.
#
# | **Operation** | **Input-1** | **Input-2** | **Output** |
# | --- | --- | --- | --- |
# | **AND** | 0 | 0 | 0 |
# | **AND** | 0 | 1 | 0 |
# | **AND** | 1 | 0 | 0 |
# | **AND** | 1 | 1 | 1 |
# | **OR** | 0 | 0 | 0 |
# | **OR** | 0 | 1 | 1 |
# | **OR** | 1 | 0 | 1 |
# | **OR** | 1 | 1 | 1 |
# | **NOT** | 0 | NA | 1 |
# | **NOT** | 1 | NA | 0 |
# | **XOR** | 0 | 0 | 0 |
# | **XOR** | 0 | 1 | 1 |
# | **XOR** | 1 | 0 | 1 |
# | **XOR** | 1 | 1 | 0 |
#
# They will be highly useful while extracting any part of the image (as we will see in coming modules), defining and working with non-rectangular ROI etc.

# %%
a = np.uint8([180])
b = np.uint8([230])
print(a)
print(b)
print()


print('AND')
print(str(bin(int(a))).replace('b', ''), ' - ', a[0])
print(str(bin(int(b))).replace('b', ''), ' - ', b[0])
print('------------')
c = cv2.bitwise_and(a, b)
print(str(bin(int(c))).replace('b', ''), ' - ', int(c))
print()

print('OR')
print(str(bin(int(a))).replace('b', ''), ' - ', a[0])
print(str(bin(int(b))).replace('b', ''), ' - ', b[0])
print('------------')
c = cv2.bitwise_or(a, b)
print(str(bin(int(c))).replace('b', ''), ' - ', int(c))
print()

print('XOR')
print(str(bin(int(a))).replace('b', ''), ' - ', a[0])
print(str(bin(int(b))).replace('b', ''), ' - ', b[0])
print('------------')
c = cv2.bitwise_xor(a, b)
print('0'+str(bin(int(c))).replace('b', ''), ' - ', int(c))
print()

print('NOT')
print(str(bin(int(a))).replace('b', ''), ' - ', a[0])
# print(str(bin(int(b))).replace('b', ''), ' - ', b)
print('------------')
c = cv2.bitwise_not(a)
print('0'+str(bin(int(c))).replace('b', ''), ' - ', int(c))
# Out:
# [180]
# [230]
#
# AND
# 010110100  -  180
# 011100110  -  230
# ------------
# 010100100  -  164
#
# OR
# 010110100  -  180
# 011100110  -  230
# ------------
# 011110110  -  246
#
# XOR
# 010110100  -  180
# 011100110  -  230
# ------------
# 001010010  -  82
#
# NOT
# 010110100  -  180
# ------------
# 001001011  -  75

# %% [markdown]
# ## <font style="color:rgb(50,120,229)">Example</font>
#
# To understand the usage of these functions, let us take the sunglass filter example from the previous section and use bitwise operations to arrive at the same result.
#
# We will follow the same steps, but instead of arithmetic operations like MULTIPLY & ADD  , we will use bitwise operations like AND, NOT and OR.

# %%
# Import libraries
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt
# %matplotlib inline

DATA_PATH = '.'

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (6.0, 6.0)
matplotlib.rcParams['image.cmap'] = 'gray'

# %% [markdown]
# ### <font style="color:rgb(8,133,37)">Load the images </font>

# %%
# Load the Face Image
faceImagePath = os.path.join(DATA_PATH,"data/images/musk.jpg")
faceImage = cv2.imread(faceImagePath)
plt.imshow(faceImage[...,::-1])
# Make a copy
faceWithGlassesBitwise = faceImage.copy()

# Load the Sunglass image with Alpha channel
glassimagePath = os.path.join(DATA_PATH,"data/images/sunglass.png")
glassPNG = cv2.imread(glassimagePath,-1)

# Resize the image to fit over the eye region
glassPNG = cv2.resize(glassPNG,(300,100))
print("image Dimension = {}".format(glassPNG.shape))

# Separate the Color and alpha channels
glassBGR = glassPNG[:,:,0:3]
glassMask1 = glassPNG[:,:,3]

# Display the images for clarity
plt.figure(figsize=[15,15])
plt.subplot(121);plt.imshow(glassBGR[:,:,::-1]);plt.title('Color channels');
plt.subplot(122);plt.imshow(glassMask1,cmap='gray');plt.title('Alpha channel');
# Out:
# image Dimension = (100, 300, 4)

# %% [markdown]
# ### <font style="color:rgb(8,133,37)">Get the masked outputs </font>

# %%
# TRICK!
# AND
# 011111111  -  255    # MASK TRANSPARENT
# 011100110  -  230
# ------------
# 011100110  -  230    # BEACUSE THE ORIGINAL PIXEL VALUE REMAINS

# AND
# 000000000  -  0      # MASK VISIBLE
# 011100110  -  230
# ------------
# 000000000  -  0      # BECAUSE THE PIXEL TURNS BLACK

# %%
# Get the eye region from the face image
eyeROI = faceWithGlassesBitwise[150:250,140:440]

# Make the dimensions of the mask same as the input image.
# Since Face Image is a 3-channel image, we create a 3 channel image for the mask
glassMask = cv2.merge((glassMask1, glassMask1, glassMask1))

# glassMask = glassMask*0.5
# glassMask = np.uint8(glassMask)
# print(glassMask[0][0])
# print(glassMask[40][50])
# print()

# Use the mask to create the masked eye region
eye = cv2.bitwise_and(eyeROI, cv2.bitwise_not(glassMask)) # 
print('eyeROI', eyeROI[0][0])
print('glassMask', glassMask[0][0])
print('cv2.bitwise_not(glassMask)', cv2.bitwise_not(glassMask)[0][0])
print('cv2.bitwise_and(eyeROI, cv2.bitwise_not(glassMask))', cv2.bitwise_and(eyeROI[0][0], cv2.bitwise_not(glassMask[0][0])) )
print()
print('eyeROI', eyeROI[40][50])
print('glassMask', glassMask[40][50])
print('cv2.bitwise_not(glassMask)', cv2.bitwise_not(glassMask)[40][50])
print('cv2.bitwise_and(eyeROI, cv2.bitwise_not(glassMask))', cv2.bitwise_and(eyeROI[40][50], cv2.bitwise_not(glassMask[40][50])) )
print()
print('eyeROI', eyeROI[17][112])
print('glassMask', glassMask[17][112])
print('cv2.bitwise_not(glassMask)', cv2.bitwise_not(glassMask)[17][112])
print('cv2.bitwise_and(eyeROI, cv2.bitwise_not(glassMask))', cv2.bitwise_and(eyeROI[17][112], cv2.bitwise_not(glassMask[17][112])) )


# Use the mask to create the masked sunglass region
sunglass = cv2.bitwise_and(glassBGR, glassMask)

# Combine the Sunglass in the Eye Region to get the augmented image
eyeRoiFinal = cv2.bitwise_or(eye, sunglass)

# Display the intermediate results
plt.figure(figsize=[20,10])
plt.subplot(331);plt.imshow(glassMask[:,:,::-1]);plt.title("glassMask");
plt.subplot(332);plt.imshow(eyeROI[:,:,::-1]);plt.title("eyeROI");
plt.subplot(333);plt.imshow(eye[:,:,::-1]);plt.title("eye");

plt.subplot(334);plt.imshow(glassMask[:,:,::-1]);plt.title("glassMask");
plt.subplot(335);plt.imshow(glassBGR[:,:,::-1]);plt.title("glassBGR");
plt.subplot(336);plt.imshow(sunglass[:,:,::-1]);plt.title("sunglass");

plt.subplot(337);plt.imshow(eye[:,:,::-1]);plt.title("eye");
plt.subplot(338);plt.imshow(sunglass[:,:,::-1]);plt.title("sunglass");
plt.subplot(339);plt.imshow(eyeRoiFinal[:,:,::-1]);plt.title("eyeRoiFinal");
# Out:
# eyeROI [32 37 46]
# glassMask [0 0 0]
# cv2.bitwise_not(glassMask) [255 255 255]
# cv2.bitwise_and(eyeROI, cv2.bitwise_not(glassMask)) [[32]
#  [37]
#  [46]]
#
# eyeROI [ 99 128 209]
# glassMask [255 255 255]
# cv2.bitwise_not(glassMask) [0 0 0]
# cv2.bitwise_and(eyeROI, cv2.bitwise_not(glassMask)) [[0]
#  [0]
#  [0]]
#
# eyeROI [153 182 249]
# glassMask [71 71 71]
# cv2.bitwise_not(glassMask) [184 184 184]
# cv2.bitwise_and(eyeROI, cv2.bitwise_not(glassMask)) [[152]
#  [176]
#  [184]]

# %% [markdown]
# ### <font style="color:rgb(8,133,37)">Get the final Result</font>

# %%
# Replace the eye ROI with the output from the previous section
face = faceWithGlassesBitwise.copy()

face[150:250,140:440]=eyeRoiFinal

# Display the final result
plt.figure(figsize=[20,20]);
plt.subplot(121);plt.imshow(faceImage[:,:,::-1]); plt.title("Original Image");
plt.subplot(122);plt.imshow(face[:,:,::-1]);plt.title("With Sunglasses");
